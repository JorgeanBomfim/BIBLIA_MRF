# %%
### importando as bibliotecas necessárias 
import requests
import pandas as pd

api_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlR1ZSBEZWMgMTkgMjAyMyAxNDoyNzoxNCBHTVQrMDAwMC42NTgwODliNjA0NDIxNzAwMmI4ODRkNzYiLCJpYXQiOjE3MDI5OTYwMzR9.TTSoC7xREuW7Akqf_sH_ifsz5uktsRJLRT9fWyS6v2Y'

# %%
### Requisitando login e senha do usuario, para poder gerar o bearer token e iniciar o uso da aplicação

## Dados de autenticação
email = "Jorgeanteste@email.com"
password = '12345678'

## URL do endpoint 
url_obter_usuario = 'https://www.abibliadigital.com.br/api/users/token'

## Corpo da requisição

body_obter_usuario = {
  "email": email,
  "password": password,
}

# requisição PUT
response = requests.put(url_obter_usuario, json=body_obter_usuario)

if response.status_code == 200:
    dados_usuario = response.json()
# Exiba os dados do usuário ou faça o que for necessário
    print(f"Token de usuário: {dados_usuario['token']}")
else:
    print(f'Erro ao obter token de usuário. Código de status: {response.status_code}')

## api_token vai receber o token do usuário
api_token = dados_usuario['token']

# %%
### Consultando livro, e capitulo. Utilizando a credencial gerada através do login

# Defina os parâmetros da requisição
version = 'ra'  # Substitua pela versão desejada
abbrev = 'sl'    # Substitua pela abreviação do livro desejado
chapter_number = 150  # Substitua pelo número do capítulo desejado

# Construa a URL com os parâmetros
url = f'https://www.abibliadigital.com.br/api/verses/{version}/{abbrev}/{chapter_number}'

# Faça a requisição GET com o token no cabeçalho
headers = {'Authorization': f'Bearer {api_token}'}
response = requests.get(url, headers=headers)

# Verifique se a requisição foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Parseie a resposta JSON
    dados_versiculos = response.json()

    # Exiba os versículos
    livro_nome = dados_versiculos['book']['name']
    capitulo_numero = dados_versiculos['chapter']['number']
    
    versiculos = []
    for versiculo in dados_versiculos['verses']:
        versiculos.append(f"{versiculo['number']}. {versiculo['text']}")

    # Atribua a variável para uso posterior
    texto_versiculos = {
        'livro': livro_nome,
        'capitulo': capitulo_numero,
        'versiculos': versiculos
    }

    # Exiba ou retorne os versículos
    print(f"{livro_nome} {capitulo_numero}")
    for versiculo in versiculos:
        print(versiculo)
else:
    # Em caso de erro
    mensagem_erro = f'Erro ao obter versículos. Código de status: {response.status_code}'
    print(mensagem_erro)
    texto_versiculos = None  # Ou qualquer outro valor que faça sentido em caso de erro

# %%
texto_versiculos

# %%
texto_versiculos

# %%
## consulta de livros, capitulos 

url_livros = 'https://www.abibliadigital.com.br/api/books'
# Faça a requisição GET com o token no cabeçalho
headers = {'Authorization': f'Bearer {api_token}'}
response = requests.get(url_livros, headers=headers)

# Verifique se a requisição foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Parseie a resposta JSON
    dados_livros = response.json()

    df_livros = pd.DataFrame(dados_livros)


    # Extrair valores de 'abbrev' para colunas separadas
    df_livros['abbrev_pt'] = df_livros['abbrev'].apply(lambda x: x['pt'])
    df_livros['abbrev_en'] = df_livros['abbrev'].apply(lambda x: x['en'])

    # Descartar a coluna 'abbrev'
    df_livros.drop(['abbrev','abbrev_en'], axis=1, inplace=True)
else:
    print(f'Erro ao os livros. Código de status: {response.status_code}')

## Renomeando as colunas para um melhor entendimento de variáveis
df_livros.rename(columns={'name':'livros','testament':'testamento',
                          'chapters':'capitulo','author':'autor'},inplace=True)

# %%
opcoes_de_livros = df_livros['livros'].unique()
qnt_de_capit_do_livro_selec = df_livros.query("livros == 'Êxodo'").loc[:,'capitulo'].iloc[-1]
opcoes_de_capitulos = list(range(1, qnt_de_capit_do_livro_selec + 1))

# %%
df_livros.query("livros == 'Deuteronômio'	")

# %%
df_livros
# Out:
#      autor  capitulo       group        livros testamento abbrev_pt
# 0   Moisés        50  Pentateuco       Gênesis         VT        gn
# 1   Moisés        40  Pentateuco         Êxodo         VT        ex
# 2   Moisés        27  Pentateuco      Levítico         VT        lv
# 3   Moisés        36  Pentateuco       Números         VT        nm
# 4   Moisés        34  Pentateuco  Deuteronômio         VT        dt
# ..     ...       ...         ...           ...        ...       ...
# 61    João         5      Cartas       1ª João         NT       1jo
# 62    João         1      Cartas       2ª João         NT       2jo
# 63    João         1      Cartas       3ª João         NT       3jo
# 64   Judas         1      Cartas         Judas         NT        jd
# 65    João        22  Revelações    Apocalipse         NT        ap
#
# [66 rows x 6 columns]

# %%
## consulta de livros, capitulos 
url_versao = 'https://www.abibliadigital.com.br/api/versions'
# Faça a requisição GET com o token no cabeçalho
headers = {'Authorization': f'Bearer {api_token}'}
response = requests.get(url_versao, headers=headers)

# Verifique se a requisição foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Parseie a resposta JSON
    dados_versoes = response.json()

    dados_versoes = pd.DataFrame(dados_versoes)

opcoes_de_versoes = dados_versoes['version'].unique()
opcoes_de_versoes

# %%
## consulta de livros, capitulos 

body_pesquisar_palavra = {
  "version": "ra",
  "search": "chorou"
}

url_pesquisar_palavra = 'https://www.abibliadigital.com.br/api/verses/search'
# Faça a requisição GET com o token no cabeçalho
headers = {'Authorization': f'Bearer {api_token}'}
response_palavra = requests.post(url_pesquisar_palavra, headers=headers, json= body_pesquisar_palavra)

# Verifique se a requisição foi bem-sucedida (código de status 200)
if response_palavra.status_code == 200:
    # Parseie a resposta JSON
    palavra_pesquisada = response_palavra.json()

    # Itera sobre cada versículo retornado
    for versiculo in palavra_pesquisada['verses']:
        # Obtém as informações do versículo
        livro_nome_palavra = versiculo['book']['name']
        capitulo_numero_palavra = versiculo['chapter']
        versiculo_numero = versiculo['number']
        versiculo_texto = versiculo['text']

        # Exibe as informações do versículo
        print(f"{livro_nome_palavra} {capitulo_numero_palavra}:{versiculo_numero}. {versiculo_texto}")

else:
    print(f'Erro ao pesquisar palavra. Código de status: {response_palavra.status_code}')
# Out:
# Gênesis 21:16. e foi assentar-se em frente dele, a boa distância, como a de um tiro de arco; porque dizia: Que não veja eu morrer o menino. Assim sentada em frente dele, levantou a sua voz e chorou.
# Gênesis 27:38. Disse Esaú a seu pai: Porventura tens uma única bênção, meu pai? Abençoa-me também a mim, meu pai. E levantou Esaú a voz, e chorou.
# Isaías 38:3. e disse: Lembra-te agora, ó Senhor, peço-te, de que modo tenho andado diante de ti em verdade, e com coração perfeito, e tenho feito o que era reto aos teus olhos. E chorou Ezequias amargamente.
# Oséias 12:4. Lutou com o anjo, e prevaleceu; chorou, e lhe fez súplicas. Em Betel o achou, e ali falou Deus com ele;
# Mateus 26:75. E Pedro lembrou-se do que dissera Jesus: Antes que o galo cante, três vezes me negarás. E, saindo dali, chorou amargamente.
# Lucas 19:41. E quando chegou perto e viu a cidade, chorou sobre ela,
# Lucas 22:61. E, havendo saído, chorou amargamente.
# João 11:35. Jesus chorou.

# %%
def pesquisar_palavra(versao, palavra):
    body_pesquisar_palavra = {
        "version": versao,
        "search": palavra
    }

    url_pesquisar_palavra = 'https://www.abibliadigital.com.br/api/verses/search'
    # Faça a requisição GET com o token no cabeçalho
    headers = {'Authorization': f'Bearer {api_token}'}
    response_palavra = requests.post(url_pesquisar_palavra, headers=headers, json=body_pesquisar_palavra)

    # Lista para armazenar as strings formatadas dos resultados
    resultados_formatados = []

    # Verifique se a requisição foi bem-sucedida (código de status 200)
    if response_palavra.status_code == 200:
        # Parseie a resposta JSON
        palavra_pesquisada = response_palavra.json()

        # Itera sobre cada versículo retornado
        for versiculo in palavra_pesquisada['verses']:
            # Obtém as informações do versículo
            livro_nome_palavra = versiculo['book']['name']
            capitulo_numero_palavra = versiculo['chapter']
            versiculo_numero = versiculo['number']
            versiculo_texto = versiculo['text']

            # Adiciona a string formatada à lista de resultados
            resultados_formatados.append(
                f"{livro_nome_palavra} {capitulo_numero_palavra}:{versiculo_numero}. {versiculo_texto}"
            )

    else:
        print(f'Erro ao pesquisar palavra. Código de status: {response_palavra.status_code}')

    # Retorna a lista de resultados formatados como strings
    return resultados_formatados


versao = 'ra'
palavra = "chorou"

# Chama a função e obtém os resultados formatados
resultados_formatados = pesquisar_palavra(versao, palavra)

# Exibe os resultados
for resultado_formatado in resultados_formatados:
    print(resultado_formatado)
# Out:
# Gênesis 21:16. e foi assentar-se em frente dele, a boa distância, como a de um tiro de arco; porque dizia: Que não veja eu morrer o menino. Assim sentada em frente dele, levantou a sua voz e chorou.
# Gênesis 27:38. Disse Esaú a seu pai: Porventura tens uma única bênção, meu pai? Abençoa-me também a mim, meu pai. E levantou Esaú a voz, e chorou.
# Gênesis 29:11. Então Jacó beijou a Raquel e, levantando a voz, chorou.
# Gênesis 37:35. E levantaram-se todos os seus filhos e todas as suas filhas, para o consolarem; ele, porém, recusou ser consolado, e disse: Na verdade, com choro hei de descer para meu filho até o Seol. Assim o chorou seu pai.
# Gênesis 42:24. Nisto José se retirou deles e chorou. Depois tornou a eles, falou-lhes, e tomou a Simeão dentre eles, e o amarrou perante os seus olhos.
# Gênesis 43:30. E José apressou-se, porque se lhe comoveram as entranhas por causa de seu irmão, e procurou onde chorar; e, entrando na sua câmara, chorou ali.
